# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

plt.style.use('dark_background')

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Create data

# %%
nPts = 24*7*4*2

period1 = 24
period2 = 24*7

x = np.arange(nPts)
y = x*10/nPts + \
    np.sin( 2*np.pi*x/period1 ) + \
    np.sin( 2*np.pi*x/period2 ) + \
    np.random.normal(0,0.0,nPts) + 10

idX = pd.date_range(start='01/01/2021', periods=nPts, freq='h')

y = pd.Series(y, index=idX)
y = y.diff().fillna(0)

y[:24*7*4].plot(figsize=(10,4))
# Out:
# <Axes: >

# %%
X = pd.DataFrame(index=idX)

X['hour']       = idX.hour
X['dayofweek']  = idX.dayofweek
X['dayofmonth'] = idX.day
X['week']       = idX.isocalendar().week.astype(int)
X['month']      = idX.month
X['quarter']    = idX.quarter
X['year']       = idX.year

from numpy import pi

for i in range(1,24//2+1):
    X[f'hour_sin{i}'] = np.sin(i*2*pi*X.hour/24)
    X[f'hour_cos{i}'] = np.cos(i*2*pi*X.hour/24)
# end

for i in range(1,7//2):
    X[f'dayofweek_sin{i}'] = np.sin(i*2*pi*X.dayofweek/7)
    X[f'dayofweek_cos{i}'] = np.cos(i*2*pi*X.dayofweek/7)
# end

for i in range(1,31//2):
    X[f'dayofmonth_sin{i}'] = np.sin(i*2*pi*X.dayofmonth/31)
    X[f'dayofmonth_cos{i}'] = np.cos(i*2*pi*X.dayofmonth/31)
# end

for i in range(1,53//2):
    X[f'year_sin{i}'] = np.sin(i*2*pi*X.year/53)
    X[f'year_cos{i}'] = np.cos(i*2*pi*X.year/53)
# end

for i in range(1,12//2+1):
    X[f'month_sin{i}'] = np.sin(i*2*pi*X.month/12)
    X[f'month_cos{i}'] = np.cos(i*2*pi*X.month/12)
# end

for i in range(1,4//2+1):
    X[f'quarter_sin{i}'] = np.sin(i*2*pi*X.quarter/4)
    X[f'quarter_cos{i}'] = np.cos(i*2*pi*X.quarter/4)
# end

X
# Out:
#                      hour  dayofweek  dayofmonth  week  month  quarter  year  \
# 2021-01-01 00:00:00     0          4           1    53      1        1  2021
# 2021-01-01 01:00:00     1          4           1    53      1        1  2021
# 2021-01-01 02:00:00     2          4           1    53      1        1  2021
# 2021-01-01 03:00:00     3          4           1    53      1        1  2021
# 2021-01-01 04:00:00     4          4           1    53      1        1  2021
# ...                   ...        ...         ...   ...    ...      ...   ...
# 2021-02-25 19:00:00    19          3          25     8      2        1  2021
# 2021-02-25 20:00:00    20          3          25     8      2        1  2021
# 2021-02-25 21:00:00    21          3          25     8      2        1  2021
# 2021-02-25 22:00:00    22          3          25     8      2        1  2021
# 2021-02-25 23:00:00    23          3          25     8      2        1  2021
#
#                      hour_sin1  hour_cos1  hour_sin2     hour_cos2  \
# 2021-01-01 00:00:00   0.000000   1.000000   0.000000  1.000000e+00
# 2021-01-01 01:00:00   0.258819   0.965926   0.500000  8.660254e-01
# 2021-01-01 02:00:00   0.500000   0.866025   0.866025  5.000000e-01
# 2021-01-01 03:00:00   0.707107   0.707107   1.000000  6.123234e-17
# 2021-02-25 20:00:00    0.500000    0.866025        -0.5  1.224647e-16
# 2021-02-25 21:00:00    0.500000    0.866025        -0.5  1.224647e-16
# 2021-02-25 22:00:00    0.500000    0.866025        -0.5  1.224647e-16
# 2021-02-25 23:00:00    0.500000    0.866025        -0.5  1.224647e-16
#
#                        month_cos3  month_sin4  month_cos4  month_sin5  \
# 2021-01-01 00:00:00  6.123234e-17    0.866025        -0.5    0.500000
# 2021-01-01 01:00:00  6.123234e-17    0.866025        -0.5    0.500000
# 2021-01-01 02:00:00  6.123234e-17    0.866025        -0.5    0.500000
# 2021-01-01 03:00:00  6.123234e-17    0.866025        -0.5    0.500000
# 2021-01-01 04:00:00  6.123234e-17    0.866025        -0.5    0.500000
# ...                           ...         ...         ...         ...
# 2021-02-25 19:00:00 -1.000000e+00   -0.866025        -0.5   -0.866025
# 2021-02-25 20:00:00 -1.000000e+00   -0.866025        -0.5   -0.866025
# 2021-02-25 21:00:00 -1.000000e+00   -0.866025        -0.5   -0.866025
# 2021-02-25 22:00:00 -1.000000e+00   -0.866025        -0.5   -0.866025
# 2021-02-25 23:00:00 -1.000000e+00   -0.866025        -0.5   -0.866025
#
#                      month_cos5    month_sin6  month_cos6  quarter_sin1  \
# 2021-01-01 00:00:00   -0.866025  1.224647e-16        -1.0           1.0
# 2021-01-01 01:00:00   -0.866025  1.224647e-16        -1.0           1.0
# 2021-01-01 02:00:00   -0.866025  1.224647e-16        -1.0           1.0
# 2021-01-01 03:00:00   -0.866025  1.224647e-16        -1.0           1.0
# 2021-01-01 04:00:00   -0.866025  1.224647e-16        -1.0           1.0
# ...                         ...           ...         ...           ...
# 2021-02-25 19:00:00    0.500000 -2.449294e-16         1.0           1.0
# 2021-02-25 20:00:00    0.500000 -2.449294e-16         1.0           1.0
# 2021-02-25 21:00:00    0.500000 -2.449294e-16         1.0           1.0
# 2021-02-25 22:00:00    0.500000 -2.449294e-16         1.0           1.0
# 2021-02-25 23:00:00    0.500000 -2.449294e-16         1.0           1.0
#
#                      quarter_cos1  quarter_sin2  quarter_cos2
# 2021-01-01 00:00:00  6.123234e-17  1.224647e-16          -1.0
# 2021-01-01 01:00:00  6.123234e-17  1.224647e-16          -1.0
# 2021-01-01 02:00:00  6.123234e-17  1.224647e-16          -1.0
# 2021-01-01 03:00:00  6.123234e-17  1.224647e-16          -1.0
# 2021-01-01 04:00:00  6.123234e-17  1.224647e-16          -1.0
# ...                           ...           ...           ...
# 2021-02-25 19:00:00  6.123234e-17  1.224647e-16          -1.0
# 2021-02-25 20:00:00  6.123234e-17  1.224647e-16          -1.0
# 2021-02-25 21:00:00  6.123234e-17  1.224647e-16          -1.0
# 2021-02-25 22:00:00  6.123234e-17  1.224647e-16          -1.0
# 2021-02-25 23:00:00  6.123234e-17  1.224647e-16          -1.0
#
# [1344 rows x 129 columns]

# %%
idx_split = int(np.round((X.shape[0] * 0.8)))
print(idx_split)

X_train = X.iloc[:idx_split,:]
y_train = y[:idx_split]

X_test  = X.iloc[idx_split:,:]
y_test  = y[idx_split:]

plt.figure(figsize=(7,3))
plt.plot( y_train, 'b', label='Train' );
plt.plot( y_test, 'r', label='Test' );
plt.legend()
# Out:
# 1075

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

models = [
    LinearRegression(),
    KNeighborsRegressor(n_neighbors=5, weights='uniform'),
    RandomForestRegressor(n_estimators=100, max_depth=5),
    RandomForestRegressor(n_estimators=100, max_depth=10),
    GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=2),
    GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3),
    GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=5),
]

# %%
from sklearn.metrics import r2_score, mean_squared_error

for m in models:
    m.fit(X_train, y_train)
    
    y_train_pred = m.predict(X_train)
    y_test_pred  = m.predict(X_test)
    
    print(m)
    
    r2_train = r2_score(y_train, y_train_pred)
    print(f'r2_train:   {r2_train:.5}')

    r2_test = r2_score(y_test, y_test_pred)
    print(f'r2_test:    {r2_test:.5}')
    
    rmse_train = mean_squared_error(y_train, y_train_pred)**0.5
    print(f'rmse_train: {rmse_train:.5}')

    rmse_test = mean_squared_error(y_test, y_test_pred)**0.5
    print(f'rmse_test:  {rmse_test:.5}')
    
    y_train_pred = pd.Series(y_train_pred, index=y_train.index)
    y_test_pred  = pd.Series(y_test_pred, index=y_test.index)

    # Calculate global y-axis limits
    y_min = min(y_train.min(), y_train_pred.min(), y_test.min(), y_test_pred.min())
    y_max = max(y_train.max(), y_train_pred.max(), y_test.max(), y_test_pred.max())

    # Plot train and test side by side with shared y limits
    fig, axs = plt.subplots(1, 2, figsize=(14, 5))

    axs[0].plot(y_train, 'r', label='True')
    axs[0].plot(y_train_pred, 'g', label='Predicted')
    axs[0].set_title('Train Set')
    axs[0].set_ylim(y_min, y_max)
    axs[0].legend()

    axs[1].plot(y_test, 'r', label='True')
    axs[1].plot(y_test_pred, 'g', label='Predicted')
    axs[1].set_title('Test Set')
    axs[1].set_ylim(y_min, y_max)
    axs[1].legend()

    plt.tight_layout()
    plt.show()
    print()
# end
# Out:
# LinearRegression()
# r2_train:   0.56903
# r2_test:    0.49529
# rmse_train: 0.15557
# rmse_test:  0.17159
# KNeighborsRegressor()
# r2_train:   0.59164
# r2_test:    0.50635
# rmse_train: 0.15144
# rmse_test:  0.1697
# RandomForestRegressor(max_depth=5)
# r2_train:   0.67489
# r2_test:    0.57215
# rmse_train: 0.13512
# rmse_test:  0.15798
# RandomForestRegressor(max_depth=10)
# r2_train:   0.87404
# r2_test:    0.56266
# rmse_train: 0.084106
# rmse_test:  0.15973
# GradientBoostingRegressor(max_depth=2)
# r2_train:   0.65338
# r2_test:    0.57497
# rmse_train: 0.13952
# rmse_test:  0.15746
# GradientBoostingRegressor()
# r2_train:   0.72035
# r2_test:    0.56578
# rmse_train: 0.12532
# rmse_test:  0.15916
# GradientBoostingRegressor(max_depth=5)
# r2_train:   0.91877
# r2_test:    0.49426
# rmse_train: 0.067541
# rmse_test:  0.17177
